# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra-Aliyeva/Data-analysis/blob/main/Zara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/zara.csv', sep=';')
df
# Out:
#      Product ID Product Position Promotion Product Category Seasonal  \
# 0        185102            Aisle        No         Clothing       No
# 1        188771            Aisle        No         Clothing       No
# 2        180176          End-cap       Yes         Clothing      Yes
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# ..          ...              ...       ...              ...      ...
# 247      159182   Front of Store       Yes         Clothing       No
# 248      199233            Aisle       Yes         Clothing       No
# 249      137044            Aisle        No         Clothing      Yes
# 250      154736   Front of Store       Yes         Clothing      Yes
# 251      141434   Front of Store        No         Clothing      Yes
#
#      Sales Volume brand                                                url  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product ID        252 non-null    int64
#  1   Product Position  252 non-null    object
#  2   Promotion         252 non-null    object
#  3   Product Category  252 non-null    object
#  4   Seasonal          252 non-null    object
#  5   Sales Volume      252 non-null    int64
#  6   brand             252 non-null    object
#  7   url               252 non-null    object
#  8   sku               252 non-null    object
#  9   name              251 non-null    object
#  10  description       250 non-null    object
#  11  price             252 non-null    float64
#  12  currency          252 non-null    object
#  13  scraped_at        252 non-null    object
#  14  terms             252 non-null    object
#  15  section           252 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Product ID', 'Product Position', 'Promotion', 'Product Category',
#        'Seasonal', 'Sales Volume', 'brand', 'url', 'sku', 'name',
#        'description', 'price', 'currency', 'scraped_at', 'terms', 'section'],
#       dtype='object')

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Product ID Product Position Promotion Product Category Seasonal  \
# 60      151925          End-cap       Yes         Clothing      Yes
# 72      173576          End-cap       Yes         Clothing       No
#
#     Sales Volume brand                                                url  \
# 60          2179  Zara  https://www.zara.com/us/en/vintage-effect-leat...
# 72          1838  Zara         https://www.zara.com/us/en/-p04310461.html
#
#                  sku                                  name description  price  \
# 60  320774184-800-97  VINTAGE EFFECT LEATHER BOMBER JACKET         NaN  299.0
# 72   336378923-700-2                                   NaN         NaN  129.0
#
#    currency                  scraped_at    terms section
# 60      USD  2024-02-19T08:50:43.543555  jackets     MAN
# 72      USD  2024-02-19T08:50:54.476057  jackets     MAN

# %%
df['description'] = df['description'].fillna(df['Product ID'].astype(str) + df['name'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sort_values('price', ascending=False).head(5)
# Out:
#     Product ID Product Position Promotion Product Category Seasonal  \
# 13      151396   Front of Store       Yes         Clothing      Yes
# 38      114877            Aisle        No         Clothing       No
# 22      161909            Aisle       Yes         Clothing       No
# 60      151925          End-cap       Yes         Clothing      Yes
# 67      154016          End-cap       Yes         Clothing      Yes
#
#     Sales Volume brand                                                url  \
# 13           729  Zara  https://www.zara.com/us/en/cropped-leather-jac...
# 38          1860  Zara  https://www.zara.com/us/en/suede-jacket-p02521...
# 22          1290  Zara  https://www.zara.com/us/en/leather-jacket-p054...
# 60          2179  Zara  https://www.zara.com/us/en/vintage-effect-leat...
# 67          2366  Zara  https://www.zara.com/us/en/wool-blend-textured...
#
#                  sku                                  name  \
# ...

# %%
df[(df['terms']=="jackets")&(df['price']>100)]
# Out:
#      Product ID Product Position Promotion Product Category Seasonal  \
# 1        188771            Aisle        No         Clothing       No
# 2        180176          End-cap       Yes         Clothing      Yes
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# 7        182157            Aisle        No         Clothing       No
# ..          ...              ...       ...              ...      ...
# 128      185800          End-cap        No         Clothing      Yes
# 245      112194            Aisle       Yes         Clothing      Yes
# 246      113435            Aisle        No         Clothing      Yes
# 247      159182   Front of Store       Yes         Clothing       No
# 248      199233            Aisle       Yes         Clothing       No
#
#      Sales Volume brand                                                url  \
# ...

# %%
df['price'].plot()
# Out:
# <Axes: >

# %%
df['price'].plot(kind='hist')
df.plot(x='Product ID', y='price', kind='scatter')
# Out:
# <Axes: xlabel='Product ID', ylabel='price'>

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing    252
# Name: count, dtype: int64

# %%
df.groupby('Product Category')['price'].mean()
# Out:
# Product Category
# Clothing    86.25254
# Name: price, dtype: float64

# %%
df['section'].unique()
# Out:
# array(['MAN', 'WOMAN'], dtype=object)

# %%
df['Seasonal'].value_counts(normalize=True) * 100
# Out:
# Seasonal
# Yes    50.793651
# No     49.206349
# Name: proportion, dtype: float64

# %%
df.groupby('Seasonal')['price'].agg(['min','mean','max'])
# Out:
#            min       mean    max
# Seasonal
# No        9.99  86.422903  349.0
# Yes       7.99  86.087500  439.0

# %%
(df['Promotion'] == 'Yes').sum()
# Out:
# np.int64(120)

# %%
df.loc[df.groupby("section")['price'].idxmax(), ['section','name','price']]
# Out:
#     section                         name  price
# 13      MAN       CROPPED LEATHER JACKET  439.0
# 169   WOMAN  CASHMERE BLEND KNIT SWEATER  169.0

# %%
df['desc_len'] = df['description'].str.len()
df.sort_values('desc_len', ascending=False).head(5)
# Out:
#     Product ID Product Position Promotion Product Category Seasonal  \
# 87      152723            Aisle        No         Clothing      Yes
# 75      162883   Front of Store       Yes         Clothing       No
# 9       137121            Aisle        No         Clothing      Yes
# 49      133100          End-cap       Yes         Clothing       No
# 94      167640          End-cap       Yes         Clothing      Yes
#
#     Sales Volume brand                                                url  \
# 87          2849  Zara  https://www.zara.com/us/en/longline-quilted-ja...
# 75           786  Zara  https://www.zara.com/us/en/technical-padded-ja...
# 9            656  Zara  https://www.zara.com/us/en/100-feather-fill-pu...
# 49          2729  Zara  https://www.zara.com/us/en/puffer-jacket-with-...
# 94          1017  Zara  https://www.zara.com/us/en/hooded-technical-ja...
#
#                  sku                             name  \
# ...

# %%
df.groupby('Seasonal')['price'].describe()
# Out:
#           count       mean        std   min   25%     50%    75%    max
# Seasonal
# No        124.0  86.422903  48.413318  9.99  49.9  79.900  109.0  349.0
# Yes       128.0  86.087500  55.598189  7.99  49.9  69.945  109.0  439.0

# %%
df.loc[df.groupby("Product Position")['price'].idxmax(), ['Product Position', 'name', 'price', 'Promotion']]
# Out:
#    Product Position                                  name  price Promotion
# 38            Aisle                          SUEDE JACKET  349.0        No
# 60          End-cap  VINTAGE EFFECT LEATHER BOMBER JACKET  299.0       Yes
# 13   Front of Store                CROPPED LEATHER JACKET  439.0       Yes

# %%
df["price"] = pd.to_numeric(df["price"], errors="coerce")
df.groupby("Promotion")["price"].mean()
# Out:
# Promotion
# No     80.651515
# Yes    92.413667
# Name: price, dtype: float64
